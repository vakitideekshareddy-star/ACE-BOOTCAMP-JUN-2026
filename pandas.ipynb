# %%
import pandas as pd
dframe = pd.read_csv('ai_student_impact_dataset (1).csv')
dframe
print(dframe.head())

print(dframe.iloc[1])
dframe.iloc[2:6, [0,1,2,5,9]]
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
dframe.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
dframe
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
dframe.set_index("Major_Category")
# Out:
#                 Student_ID Year_of_Study  Pre_Semester_GPA  \
# Major_Category
# Humanities          100001        Senior             2.418
# Medical             100002        Junior             3.821
# Business            100003      Freshman             3.398
# Business            100004        Senior             3.789
# STEM                100005     Sophomore             3.635
# ...                    ...           ...               ...
# Business            149996        Senior             2.899
# STEM                149997        Senior             2.870
# Business            149998        Senior             3.177
# Business            149999        Junior             3.398
# Arts                150000     Sophomore             3.242
#
#                 Weekly_GenAI_Hours           Primary_Use_Case  \
# Major_Category
# Humanities                   23.31       Copywriting/Drafting
# Medical                       1.12                   Ideation
# ...

# %%
dframe.loc[50:70, ['Major_Category','Year_of_Study','Pre_Semester_GPA']]
# Out:
#    Major_Category Year_of_Study  Pre_Semester_GPA
# 50        Medical     Sophomore             3.577
# 51           Arts        Senior             2.433
# 52        Medical     Sophomore             2.958
# 53        Medical        Senior             3.732
# 54       Business        Junior             3.148
# 55        Medical        Senior             3.429
# 56           STEM        Junior             3.837
# 57           STEM     Sophomore             3.249
# 58           STEM        Junior             3.015
# 59     Humanities     Sophomore             3.167
# 60     Humanities     Sophomore             3.697
# 61           STEM      Freshman             3.463
# 62           Arts        Senior             2.164
# 63     Humanities      Freshman             2.771
# 64           STEM      Graduate             3.569
# 65       Business      Freshman             3.074
# 66           STEM      Graduate             3.329
# 67           Arts      Graduate             3.606
# ...

# %%
dframe.columns
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours',
#        'Perceived_AI_Dependency', 'Institutional_Policy',
#        'Anxiety_Level_During_Exams', 'Post_Semester_GPA',
#        'Skill_Retention_Score', 'Burnout_Risk_Level'],
#       dtype='object')

# %%
dframe.loc[:, 'Tool_Diversity']== 5 
#dframe.loc[:,'Post_Semester_GPA']==4.00
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997     True
# 49998     True
# 49999    False
# Name: Tool_Diversity, Length: 50000, dtype: bool

# %%
filt = dframe['Tool_Diversity']== 5 
dframe.loc[filt]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 1          100002        Medical        Junior             3.821
# 6          100007           STEM      Freshman             3.622
# 26         100027           STEM     Sophomore             3.338
# 33         100034        Medical        Senior             3.148
# 86         100087       Business      Graduate             3.033
# ...           ...            ...           ...               ...
# 49966      149967        Medical        Junior             2.921
# 49970      149971           STEM      Freshman             3.219
# 49984      149985       Business        Senior             3.548
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 1                    1.12                   Ideation                 Advanced
# ...

# %%
filt = dframe['Tool_Diversity']== 5 
dframe.loc[filt].head()
# Out:
#     Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 1       100002        Medical        Junior             3.821
# 6       100007           STEM      Freshman             3.622
# 26      100027           STEM     Sophomore             3.338
# 33      100034        Medical        Senior             3.148
# 86      100087       Business      Graduate             3.033
#
#     Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 1                 1.12                   Ideation                 Advanced
# 6                31.41        Summarizing_Reading                 Advanced
# 26               18.62  Debugging/Troubleshooting                 Advanced
# 33                5.56        Summarizing_Reading             Intermediate
# 86                9.65                   Ideation             Intermediate
#
#     Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 1                5              False                    16.65
# ...

# %%
filt = dframe['Tool_Diversity']== 5 
dframe.loc[filt].sort_index().head()
# Out:
#     Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 1       100002        Medical        Junior             3.821
# 6       100007           STEM      Freshman             3.622
# 26      100027           STEM     Sophomore             3.338
# 33      100034        Medical        Senior             3.148
# 86      100087       Business      Graduate             3.033
#
#     Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 1                 1.12                   Ideation                 Advanced
# 6                31.41        Summarizing_Reading                 Advanced
# 26               18.62  Debugging/Troubleshooting                 Advanced
# 33                5.56        Summarizing_Reading             Intermediate
# 86                9.65                   Ideation             Intermediate
#
#     Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 1                5              False                    16.65
# ...

# %%
filt = dframe['Tool_Diversity']== 5 
dframe.loc[filt].sort_index(ascending=False).head()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49998      149999       Business        Junior             3.398
# 49997      149998       Business        Senior             3.177
# 49984      149985       Business        Senior             3.548
# 49970      149971           STEM      Freshman             3.219
# 49966      149967        Medical        Junior             2.921
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 49998               19.91  Debugging/Troubleshooting             Intermediate
# 49997               15.87        Summarizing_Reading                 Advanced
# 49984                2.76       Copywriting/Drafting                 Advanced
# 49970               10.48       Copywriting/Drafting             Intermediate
# 49966               22.68        Summarizing_Reading                 Advanced
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# ...

# %%
filt = (dframe['Tool_Diversity']== 5) |  (dframe['Prompt_Engineering_Skill']== 'Intermediate')
dframe.loc[filt].sort_index(ascending=True).tail(50)
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49901      149902       Business        Junior             2.789
# 49905      149906       Business        Junior             1.862
# 49906      149907           STEM        Junior             2.892
# 49908      149909           STEM        Junior             3.624
# 49909      149910     Humanities        Junior             3.775
# 49910      149911       Business        Junior             3.008
# 49911      149912     Humanities      Freshman             3.058
# 49914      149915        Medical      Freshman             2.098
# 49915      149916     Humanities        Junior             2.057
# 49918      149919           STEM     Sophomore             2.132
# 49922      149923           STEM      Graduate             2.598
# 49923      149924       Business        Senior             3.032
# 49925      149926           STEM     Sophomore             3.391
# ...
